# %%
# Seaborn
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading of seaborn inbuilt dataset    
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
# Distribution Plot
# sns.histplot(df['total_bill'])
# sns.histplot(df['total_bill'] , bins=5)
sns.histplot(df['total_bill'], bins=30 , kde=True)  # with KDE
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# Subplots
plt.subplot(2,2,1)
sns.histplot(df['total_bill'], bins=30 , kde=True)
plt.subplot(2,2,2)
sns.histplot(df['tip'], bins=30 , kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# Joint Plot
sns.jointplot(x='total_bill', y='tip', data=df, kind='scatter')  # scatter plot

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='hex')  # scatter plot

# %%
# pairplot
sns.pairplot(df)  # pairwise relationships in a dataset

# %%
sns.pairplot(df, hue='sex')  # pairwise relationships in a dataset with hue based on 'sex'

# %%
# Rug Plot
sns.rugplot(df['total_bill'])  # it draws small vertical lines at each data point along the x-axis to show the distribution of data points
# Out:
# <Axes: xlabel='total_bill'>

# %%
# Rug Plot
sns.rugplot(df)  # it draws small vertical lines at each data point along the x-axis to show the distribution of data points
# Out:
# <Axes: >

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x = df['sex'], hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(x=df['sex'], y= df['total_bill'],)  # default estimator is mean
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x=df['sex'], y = df['tip'] , estimator= np.sum)    # changing estimator to sum
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x=df['tip'], y=df['day'], data=df)  # box plot showing distribution of tip amount for each day
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.boxplot(x=df['tip'], y=df['day'] , data=df , palette='rainbow')  # box plot showing distribution of tip amount for each day
# Out:
# C:\Users\MITAN TANK\AppData\Local\Temp\ipykernel_22640\66335920.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['tip'], y=df['day'] , data=df , palette='rainbow')  # box plot showing distribution of tip amount for each day
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.violinplot(x=df['day'], y=df['total_bill'], data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x=df['day'], y=df['total_bill'], data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x=df['day'], y=df['total_bill'], data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x=df['tip'], y=df['day'], data=df)
sns.swarmplot(x=df['tip'], y=df['day'], data=df)
# Out:
# c:\Users\MITAN TANK\Desktop\Programs\Python\Matplotlib\venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\MITAN TANK\Desktop\Programs\Python\Matplotlib\venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='tip', ylabel='day'>
# c:\Users\MITAN TANK\Desktop\Programs\Python\Matplotlib\venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
flights = sns.load_dataset('flights')
flights

tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tipsCorr = tips[['total_bill', 'tip', 'size']]
tipsCorr
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
# correlation matrix
tipsCorr.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tipsCorr.corr() , annot=True)  # heatmap of correlation matrix with annotations
# Out:
# <Axes: >

# %%
pivotFlight = flights.pivot_table(index='month', columns='year', values='passengers')
pivotFlight
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# Dec    118.0  140.0  166.0  194.0  201.0  229.0  278.0  306.0  336.0  337.0
#
# year    1959   1960
# month
# Jan    360.0  417.0
# Feb    342.0  391.0
# Mar    406.0  419.0
# Apr    396.0  461.0
# May    420.0  472.0
# Jun    472.0  535.0
# Jul    548.0  622.0
# Aug    559.0  606.0
# Sep    463.0  508.0
# Oct    407.0  461.0
# Nov    362.0  390.0
# Dec    405.0  432.0

# %%
sns.heatmap(pivotFlight)  # heatmap of pivot table
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.lmplot(x='total_bill', y='tip', data=df)  # regression plot with scatter plot and regression line

# %%
sns.lmplot(x='total_bill', y='tip', data=df , hue='sex')  # regression plot with scatter plot and regression line

# %%
sns.lmplot(x='total_bill', y='tip', data=df , hue='sex' , palette='rainbow' )  # regression plot with scatter plot and regression line

# %%
sns.lmplot(x='total_bill', y='tip', data=df , hue='sex' , palette='rainbow', markers=['o', 'x'])  # regression plot with scatter plot and regression line
